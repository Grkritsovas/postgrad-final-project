# %%
import librosa
import numpy as np
import pandas as pd
from pathlib import Path
from tqdm import tqdm
import soundfile as sf
import warnings
import json
from typing import Dict, Tuple, Optional

import sys
sys.path.append('..')
from src.deep_learning_audio_preprocessing import *
warnings.filterwarnings('ignore')

# %% [markdown]
# ## DEAM

# %%
# Configuration
MODEL_TYPE = 'ast'
RAW_AUDIO_DIR = Path("../data/raw/audio_files_DEAM/MEMD_audio/")
PROCESSED_DIR = Path(f"../data/processed/mel_spectrograms_{MODEL_TYPE}/")
# Create output directory
PROCESSED_DIR.mkdir(parents=True, exist_ok=True)

# %%
# Create preprocessor
preprocessor = AudioPreprocessor(model_type=MODEL_TYPE)

# %%
# Get all audio files
audio_files = list(RAW_AUDIO_DIR.glob("*.mp3"))
if not audio_files:
    audio_files = list(RAW_AUDIO_DIR.glob("*.wav"))
    
print(f"Found {len(audio_files)} audio files")
print(f"Using {MODEL_TYPE} configuration:")
print(json.dumps(preprocessor.config, indent=2))
# Out:
# Found 1802 audio files
# Using ast configuration:
# {
#   "target_sr": 16000,
#   "n_mels": 128,
#   "n_fft": 400,
#   "hop_length": 160,
#   "duration_secs": 10,
#   "normalize": "global"
# }

# %%
# Compute global statistics
if preprocessor.config['normalize'] == 'global':
    preprocessor.compute_global_stats(audio_files)
    
# Process all files
print(f"\nProcessing audio files...")
    
failed_files = []
metadata = {}
    
for audio_path in tqdm(audio_files, desc="Processing"):
    song_id = audio_path.stem
    output_path = PROCESSED_DIR / f"{song_id}.npz"
        
    if not output_path.exists():
        result = preprocessor.process_file(audio_path)
            
        if result is not None:
            # Save as compressed numpy file
            np.savez_compressed(
                output_path,
                spectrograms=result['spectrograms'],
                song_id=result['song_id']
            )
                
            metadata[song_id] = {
                'n_segments': result['n_segments'],
                'shape': result['spectrograms'].shape
            }
        else:
            failed_files.append(audio_path.name)
# Out:
# Computing global statistics from 100 files...
# Computing stats: 100%|████████████████████████████████████████████████████████████████| 100/100 [00:08<00:00, 11.54it/s]
# Global stats - Mean: -41.76, Std: 16.17
#
# Processing audio files...
# Processing: 100%|███████████████████████████████████████████████████████████████████| 1802/1802 [08:16<00:00,  3.63it/s]

# %%
# Save metadata
metadata_path = PROCESSED_DIR / 'preprocessing_metadata.json'
with open(metadata_path, 'w') as f:
    json.dump({
        'model_type': MODEL_TYPE,
        'config': preprocessor.config,
        'global_mean': float(preprocessor.global_mean) if preprocessor.global_mean is not None else None,
        'global_std': float(preprocessor.global_std) if preprocessor.global_std is not None else None,
        'n_processed': len(metadata),
        'n_failed': len(failed_files),
        'failed_files': failed_files,
        'file_metadata': metadata
    }, f, indent=2)
    
print(f"\nProcessing complete!")
print(f"Processed: {len(metadata)} files")
print(f"Failed: {len(failed_files)} files")
print(f"Metadata saved to: {metadata_path}")
# Out:
# Processing complete!
# Processed: 1802 files
# Failed: 0 files
# Metadata saved to: ../data/processed/mel_spectrograms_ast/preprocessing_metadata.json

# %%
example_id = list(metadata.keys())[0]
print(f"\nExample output shape for {example_id}: {metadata[example_id]['shape']}")
# Out:
# Example output shape for 463: (4, 128, 1001)

# %% [markdown]
# ### make a mert embedding of the audio files

# %%
from huggingface_hub import list_repo_files

# Check the correct model exists
files = list_repo_files("m-a-p/MERT-v1-95M")
print(f"Found {len(files)} files in m-a-p/MERT-v1-95M")
print("Sample files:", files[:5])
# Out:
# Found 8 files in m-a-p/MERT-v1-95M
# Sample files: ['.gitattributes', 'MERT-v1-95M_fairseq.pt', 'README.md', 'config.json', 'configuration_MERT.py']

# %%
from huggingface_hub import snapshot_download
mert_dir = snapshot_download("m-a-p/MERT-v1-95M", resume_download=False, force_download=True)
print("MERT at:", mert_dir)

from transformers import AutoModel, Wav2Vec2FeatureExtractor
_ = AutoModel.from_pretrained(mert_dir, trust_remote_code=True)
_ = Wav2Vec2FeatureExtractor.from_pretrained(mert_dir, trust_remote_code=True)
print("Local MERT loads.")
# Out:
# /home/georgios/miniconda3/envs/torch-gpu/lib/python3.10/site-packages/huggingface_hub/file_download.py:945: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# preprocessor_config.json:   0%|          | 0.00/211 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# modeling_MERT.py: 0.00B [00:00, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# .gitattributes: 0.00B [00:00, ?B/s]
# configuration_MERT.py: 0.00B [00:00, ?B/s]
# MERT-v1-95M_fairseq.pt:   0%|          | 0.00/1.32G [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/378M [00:00<?, ?B/s]
# MERT at: /home/georgios/.cache/huggingface/hub/models--m-a-p--MERT-v1-95M/snapshots/12af15fef9d0ac838c3f475bfbbf26d2060dd4f5
# Local MERT loads.

# %%
# I/O
AUDIO_DIR = Path("../data/raw/audio_files_DEAM/MEMD_audio")
MERT_OUTPUT_DIR = Path("../data/processed/mert_embeddings/")
MERT_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# %%
import torch
# Load MERT
device = "cuda" if torch.cuda.is_available() else "cpu"
model = AutoModel.from_pretrained("m-a-p/MERT-v1-95M", trust_remote_code=True)
processor = Wav2Vec2FeatureExtractor.from_pretrained("m-a-p/MERT-v1-95M", trust_remote_code=True)
model = model.to(device)
model.eval()
print(f"MERT loaded on {device}")
# Out:
# MERT loaded on cuda

# %%
import librosa
# Layers to use for the final embedding (concatenate L5 and L6 → 1536D vector)
LAYER_A, LAYER_B = 5, 6

audio_files = sorted(AUDIO_DIR.glob("*.mp3"))

with torch.inference_mode():
    for audio_path in tqdm(audio_files, desc="Extracting MERT L5+L6 embeddings"):
        out_path = MERT_OUTPUT_DIR / f"{audio_path.stem}.npy"
        if out_path.exists():# skip existing embedding files
            continue
        # Load audio (mono, resampled to 24 kHz as expected by MERT)
        audio, _ = librosa.load(audio_path, sr=24000, mono=True, duration=45.0)
        # Convert audio into MERT input format
        inputs = processor(audio, sampling_rate=24000, return_tensors="pt", padding=True)
        inputs = {k: v.to(device) for k, v in inputs.items()}

        # Run MERT and keep hidden states from all transformer layers
        outputs = model(**inputs, output_hidden_states=True)
        hs = outputs.hidden_states # list of tensors: [embedding_output, layer1, ..., layer12]

        # Pick the 5th and 6th transformer layers
        # If 13 entries, index is shifted by +1 because the first is the embedding output
        if len(hs) == 13:
            h5 = hs[LAYER_A + 1]  # (B,T,768)
            h6 = hs[LAYER_B + 1]
        else:
            h5 = hs[LAYER_A]
            h6 = hs[LAYER_B]

        # mean over time dimens, concat -> (1536,)
        v5 = h5.mean(dim=1) # (B,768)
        v6 = h6.mean(dim=1) # (B,768)
        vec = torch.cat([v5, v6], dim=-1).squeeze(0).float().cpu().numpy() # (1536,)

        # save the embedding
        out_path = MERT_OUTPUT_DIR / f"{audio_path.stem}.npy"
        np.save(out_path, vec.astype(np.float32))
# Out:
# Extracting MERT L5+L6 embeddings: 100%|████████████████████████████████████████████| 1802/1802 [00:03<00:00, 454.16it/s]

# %% [markdown]
# ## Deezer

# %%
deezer_train = pd.read_csv('../data/Deezer/train.csv')
deezer_val = pd.read_csv('../data/Deezer/val.csv')
deezer_test = pd.read_csv('../data/Deezer/test.csv')
# Combine all for preprocessing
deezer_all = pd.concat([deezer_train, deezer_val, deezer_test])

# %%
# audio files named by dzr_sng_id
MODEL_TYPE = 'ast'
audio_dir = Path('../data/raw/audio_files_Deezer/')
output_dir = Path(f'../data/processed/DEEZER/mel_spectrograms_{MODEL_TYPE}')
output_dir.mkdir(parents=True, exist_ok=True)

# %%
preprocessor = AudioPreprocessor(model_type=MODEL_TYPE)

# %%
# Get all audio files
audio_files = list(audio_dir.glob("*.mp3"))
if not audio_files:
    audio_files = list(audio_dir.glob("*.wav"))
    
print(f"Found {len(audio_files)} audio files")
print(f"Using {MODEL_TYPE} configuration:")
print(json.dumps(preprocessor.config, indent=2))
# Out:
# Found 12089 audio files
# Using ast configuration:
# {
#   "target_sr": 16000,
#   "n_mels": 128,
#   "n_fft": 400,
#   "hop_length": 160,
#   "duration_secs": 10,
#   "normalize": "global"
# }

# %%
# Compute global statistics
if preprocessor.config['normalize'] == 'global':
    preprocessor.compute_global_stats(audio_files)

# %%
metadata = {}
failed_files = []

for dzr_id in tqdm(deezer_all['dzr_sng_id'], desc="Processing Deezer"):
    audio_path = audio_dir / f"{dzr_id}.mp3"
    if not audio_path.exists():
        continue

    result = preprocessor.process_file(audio_path)
    if result is not None:
        np.savez_compressed(
            output_dir / f"{dzr_id}.npz",
            spectrograms=result['spectrograms'],
            song_id=result['song_id']
        )

        metadata[dzr_id] = {
            'n_segments': result['n_segments'],
            'shape': result['spectrograms'].shape
        }
    else:
        failed_files.append(audio_path.name)

# Save metadata
with open(output_dir / "preprocessing_metadata.json", "w") as f:
    json.dump(metadata, f, indent=2)
# Out:
#   Cell In[3], line 1
#     '''
#     ^
# SyntaxError: incomplete input

# %% [markdown]
# ### mert embeddings for Deezer

# %%
from huggingface_hub import list_repo_files

# Check the correct model exists
files = list_repo_files("m-a-p/MERT-v1-95M")
print(f"Found {len(files)} files in m-a-p/MERT-v1-95M")
print("Sample files:", files[:5])
# Out:
# Found 8 files in m-a-p/MERT-v1-95M
# Sample files: ['.gitattributes', 'MERT-v1-95M_fairseq.pt', 'README.md', 'config.json', 'configuration_MERT.py']

# %%
from huggingface_hub import snapshot_download
mert_dir = snapshot_download("m-a-p/MERT-v1-95M", resume_download=False, force_download=True)
print("MERT at:", mert_dir)

from transformers import AutoModel, Wav2Vec2FeatureExtractor
_ = AutoModel.from_pretrained(mert_dir, trust_remote_code=True)
_ = Wav2Vec2FeatureExtractor.from_pretrained(mert_dir, trust_remote_code=True)
print("Local MERT loads.")
# Out:
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# configuration_MERT.py: 0.00B [00:00, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/211 [00:00<?, ?B/s]
# modeling_MERT.py: 0.00B [00:00, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/378M [00:00<?, ?B/s]
# MERT-v1-95M_fairseq.pt:   0%|          | 0.00/1.32G [00:00<?, ?B/s]
# .gitattributes: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# MERT at: /home/georgios/.cache/huggingface/hub/models--m-a-p--MERT-v1-95M/snapshots/12af15fef9d0ac838c3f475bfbbf26d2060dd4f5
# Local MERT loads.

# %%
# I/O
AUDIO_DIR = Path("../data/raw/audio_files_Deezer/")
MERT_OUTPUT_DIR = Path("../data/processed/DEEZER/mert_embeddings/")
MERT_OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# %%
import torch
# Load MERT
device = "cuda" if torch.cuda.is_available() else "cpu"
model = AutoModel.from_pretrained("m-a-p/MERT-v1-95M", trust_remote_code=True)
processor = Wav2Vec2FeatureExtractor.from_pretrained("m-a-p/MERT-v1-95M", trust_remote_code=True)
model = model.to(device)
model.eval()
print(f"MERT loaded on {device}")
# Out:
# MERT loaded on cuda

# %%
import librosa
# Layers to use for the final embedding (concatenate L5 and L6 → 1536D vector)
LAYER_A, LAYER_B = 5, 6

audio_files = sorted(AUDIO_DIR.glob("*.mp3"))

with torch.inference_mode():
    for audio_path in tqdm(audio_files, desc="Extracting MERT L5+L6 embeddings"):
        out_path = MERT_OUTPUT_DIR / f"{audio_path.stem}.npy"
        if out_path.exists():# skip existing embedding files
            continue
        # Load audio (mono, resampled to 24 kHz as expected by MERT)
        audio, _ = librosa.load(audio_path, sr=24000, mono=True, duration=45.0)
        # Convert audio into MERT input format
        inputs = processor(audio, sampling_rate=24000, return_tensors="pt", padding=True)
        inputs = {k: v.to(device) for k, v in inputs.items()}

        # Run MERT and keep hidden states from all transformer layers
        outputs = model(**inputs, output_hidden_states=True)
        hs = outputs.hidden_states # list of tensors: [embedding_output, layer1, ..., layer12]

        # Pick the 5th and 6th transformer layers
        # If 13 entries, index is shifted by +1 because the first is the embedding output
        if len(hs) == 13:
            h5 = hs[LAYER_A + 1]  # (B,T,768)
            h6 = hs[LAYER_B + 1]
        else:
            h5 = hs[LAYER_A]
            h6 = hs[LAYER_B]

        # mean over time dimens, concat -> (1536,)
        v5 = h5.mean(dim=1) # (B,768)
        v6 = h6.mean(dim=1) # (B,768)
        vec = torch.cat([v5, v6], dim=-1).squeeze(0).float().cpu().numpy() # (1536,)

        # save the embedding
        out_path = MERT_OUTPUT_DIR / f"{audio_path.stem}.npy"
        np.save(out_path, vec.astype(np.float32))
# Out:
# Extracting MERT L5+L6 embeddings:   0%|                                                       | 0/12089 [00:00<?, ?it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   2%|▊                                           | 240/12089 [00:01<01:13, 160.80it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# [src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# [src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# [src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# [src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# [src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# [src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# [src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# [src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# [src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# [src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# [src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# [src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# [src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# [src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# [src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# [src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   2%|▉                                            | 257/12089 [00:03<03:44, 52.71it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# [src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# [src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# [src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# [src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# [src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# [src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# [src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   2%|▉                                            | 265/12089 [00:05<05:09, 38.14it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# [src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# [src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# [src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# [src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   2%|█                                            | 270/12089 [00:05<06:18, 31.23it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# [src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# [src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   2%|█                                            | 273/12089 [00:06<07:11, 27.39it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# [src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# [src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   2%|█                                            | 276/12089 [00:06<08:22, 23.51it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# [src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   2%|█                                            | 278/12089 [00:06<09:22, 21.01it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# [src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   2%|█                                            | 280/12089 [00:07<10:37, 18.51it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# [src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   2%|█                                            | 282/12089 [00:07<12:06, 16.24it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   2%|█                                            | 283/12089 [00:07<13:03, 15.06it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   2%|█                                            | 284/12089 [00:07<14:14, 13.82it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   2%|█                                            | 285/12089 [00:07<15:41, 12.54it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   2%|█                                            | 286/12089 [00:08<17:18, 11.36it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   2%|█                                            | 287/12089 [00:08<19:03, 10.32it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   2%|█                                            | 288/12089 [00:08<20:39,  9.52it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   2%|█                                            | 289/12089 [00:08<22:06,  8.90it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   2%|█                                            | 290/12089 [00:08<23:23,  8.41it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   2%|█                                            | 291/12089 [00:08<24:35,  7.99it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   2%|█                                            | 292/12089 [00:09<26:01,  7.56it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   2%|█                                            | 293/12089 [00:09<26:48,  7.33it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   2%|█                                            | 294/12089 [00:09<27:23,  7.18it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   2%|█                                            | 295/12089 [00:09<27:37,  7.12it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   2%|█                                            | 296/12089 [00:09<28:04,  7.00it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   2%|█                                            | 297/12089 [00:09<28:22,  6.93it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   2%|█                                            | 298/12089 [00:09<28:13,  6.96it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   2%|█                                            | 299/12089 [00:10<28:28,  6.90it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   2%|█                                            | 300/12089 [00:10<28:32,  6.88it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   2%|█                                            | 301/12089 [00:10<28:30,  6.89it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   2%|█                                            | 302/12089 [00:10<28:09,  6.98it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▏                                           | 303/12089 [00:10<28:23,  6.92it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▏                                           | 304/12089 [00:10<28:33,  6.88it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▏                                           | 305/12089 [00:10<28:38,  6.86it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▏                                           | 306/12089 [00:11<28:31,  6.88it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▏                                           | 307/12089 [00:11<28:43,  6.84it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▏                                           | 308/12089 [00:11<28:43,  6.84it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▏                                           | 309/12089 [00:11<28:43,  6.84it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▏                                           | 310/12089 [00:11<28:42,  6.84it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▏                                           | 311/12089 [00:11<28:37,  6.86it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▏                                           | 312/12089 [00:11<28:44,  6.83it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▏                                           | 313/12089 [00:12<29:00,  6.76it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▏                                           | 314/12089 [00:12<28:22,  6.92it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▏                                           | 315/12089 [00:12<28:30,  6.88it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▏                                           | 316/12089 [00:12<28:46,  6.82it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▏                                           | 317/12089 [00:12<28:28,  6.89it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▏                                           | 318/12089 [00:12<28:22,  6.92it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▏                                           | 319/12089 [00:12<28:18,  6.93it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▏                                           | 320/12089 [00:13<28:25,  6.90it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▏                                           | 321/12089 [00:13<28:13,  6.95it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▏                                           | 322/12089 [00:13<28:21,  6.92it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▏                                           | 323/12089 [00:13<28:38,  6.85it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▏                                           | 324/12089 [00:13<28:47,  6.81it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▏                                           | 325/12089 [00:13<28:45,  6.82it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▏                                           | 326/12089 [00:13<28:39,  6.84it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▏                                           | 327/12089 [00:14<28:41,  6.83it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▏                                           | 328/12089 [00:14<28:48,  6.80it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▏                                           | 329/12089 [00:14<28:54,  6.78it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▏                                           | 330/12089 [00:14<28:46,  6.81it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▏                                           | 331/12089 [00:14<28:41,  6.83it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▏                                           | 332/12089 [00:14<29:10,  6.72it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▏                                           | 333/12089 [00:15<29:10,  6.72it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▏                                           | 334/12089 [00:15<29:13,  6.70it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▏                                           | 335/12089 [00:15<29:21,  6.67it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▎                                           | 336/12089 [00:15<29:12,  6.71it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▎                                           | 337/12089 [00:15<28:48,  6.80it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▎                                           | 338/12089 [00:15<28:40,  6.83it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▎                                           | 339/12089 [00:15<28:35,  6.85it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▎                                           | 340/12089 [00:16<28:44,  6.81it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▎                                           | 341/12089 [00:16<28:56,  6.77it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▎                                           | 342/12089 [00:16<28:52,  6.78it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▎                                           | 343/12089 [00:16<28:41,  6.82it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▎                                           | 344/12089 [00:16<28:39,  6.83it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▎                                           | 345/12089 [00:16<28:39,  6.83it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▎                                           | 346/12089 [00:16<29:09,  6.71it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▎                                           | 347/12089 [00:17<29:03,  6.73it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▎                                           | 348/12089 [00:17<29:02,  6.74it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▎                                           | 349/12089 [00:17<28:59,  6.75it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▎                                           | 350/12089 [00:17<29:22,  6.66it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▎                                           | 351/12089 [00:17<28:59,  6.75it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▎                                           | 352/12089 [00:17<28:42,  6.81it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▎                                           | 353/12089 [00:17<28:31,  6.86it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▎                                           | 354/12089 [00:18<29:10,  6.71it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▎                                           | 355/12089 [00:18<28:27,  6.87it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▎                                           | 356/12089 [00:18<28:42,  6.81it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▎                                           | 357/12089 [00:18<28:52,  6.77it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▎                                           | 358/12089 [00:18<28:39,  6.82it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▎                                           | 359/12089 [00:18<28:20,  6.90it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▎                                           | 360/12089 [00:18<28:59,  6.74it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▎                                           | 361/12089 [00:19<28:39,  6.82it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▎                                           | 362/12089 [00:19<28:14,  6.92it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▎                                           | 363/12089 [00:19<28:15,  6.91it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▎                                           | 364/12089 [00:19<28:33,  6.84it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▎                                           | 365/12089 [00:19<28:53,  6.76it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▎                                           | 366/12089 [00:19<28:40,  6.81it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▎                                           | 367/12089 [00:19<28:16,  6.91it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▎                                           | 368/12089 [00:20<28:25,  6.87it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▎                                           | 369/12089 [00:20<28:29,  6.86it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▍                                           | 370/12089 [00:20<28:27,  6.86it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▍                                           | 371/12089 [00:20<28:31,  6.85it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▍                                           | 372/12089 [00:20<28:40,  6.81it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▍                                           | 373/12089 [00:20<28:21,  6.89it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▍                                           | 374/12089 [00:21<28:27,  6.86it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▍                                           | 375/12089 [00:21<28:18,  6.90it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▍                                           | 376/12089 [00:21<28:16,  6.90it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▍                                           | 377/12089 [00:21<28:03,  6.96it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▍                                           | 378/12089 [00:21<28:31,  6.84it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▍                                           | 379/12089 [00:21<28:37,  6.82it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▍                                           | 380/12089 [00:21<28:43,  6.79it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▍                                           | 381/12089 [00:22<28:53,  6.75it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▍                                           | 382/12089 [00:22<29:06,  6.70it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▍                                           | 383/12089 [00:22<28:43,  6.79it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▍                                           | 384/12089 [00:22<28:39,  6.81it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▍                                           | 385/12089 [00:22<28:20,  6.88it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▍                                           | 386/12089 [00:22<28:20,  6.88it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▍                                           | 387/12089 [00:22<28:32,  6.83it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▍                                           | 388/12089 [00:23<28:53,  6.75it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▍                                           | 389/12089 [00:23<28:44,  6.78it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▍                                           | 390/12089 [00:23<28:35,  6.82it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▍                                           | 391/12089 [00:23<28:25,  6.86it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▍                                           | 392/12089 [00:23<28:18,  6.89it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▍                                           | 393/12089 [00:23<28:25,  6.86it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▍                                           | 394/12089 [00:23<28:34,  6.82it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▍                                           | 395/12089 [00:24<28:23,  6.86it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▍                                           | 396/12089 [00:24<28:39,  6.80it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▍                                           | 397/12089 [00:24<28:32,  6.83it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▍                                           | 398/12089 [00:24<28:30,  6.84it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▍                                           | 399/12089 [00:24<28:43,  6.78it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▍                                           | 400/12089 [00:24<28:32,  6.83it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▍                                           | 401/12089 [00:24<28:30,  6.83it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▍                                           | 402/12089 [00:25<28:25,  6.85it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▌                                           | 403/12089 [00:25<28:14,  6.89it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▌                                           | 404/12089 [00:25<28:22,  6.86it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▌                                           | 405/12089 [00:25<28:23,  6.86it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▌                                           | 406/12089 [00:25<28:38,  6.80it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▌                                           | 407/12089 [00:25<28:33,  6.82it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▌                                           | 408/12089 [00:25<28:19,  6.87it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▌                                           | 409/12089 [00:26<28:27,  6.84it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▌                                           | 410/12089 [00:26<28:41,  6.79it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▌                                           | 411/12089 [00:26<28:30,  6.83it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▌                                           | 412/12089 [00:26<28:42,  6.78it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▌                                           | 413/12089 [00:26<28:45,  6.76it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▌                                           | 414/12089 [00:26<28:46,  6.76it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▌                                           | 415/12089 [00:27<29:00,  6.71it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▌                                           | 416/12089 [00:27<28:35,  6.80it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▌                                           | 417/12089 [00:27<28:47,  6.76it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▌                                           | 418/12089 [00:27<28:32,  6.81it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▌                                           | 419/12089 [00:27<28:10,  6.90it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▌                                           | 420/12089 [00:27<28:36,  6.80it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▌                                           | 421/12089 [00:27<28:49,  6.75it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▌                                           | 422/12089 [00:28<28:26,  6.84it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   3%|█▌                                           | 423/12089 [00:28<28:21,  6.86it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▌                                           | 424/12089 [00:28<28:12,  6.89it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▌                                           | 425/12089 [00:28<28:36,  6.79it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▌                                           | 426/12089 [00:28<28:11,  6.89it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▌                                           | 427/12089 [00:28<28:19,  6.86it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▌                                           | 428/12089 [00:28<28:11,  6.89it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▌                                           | 429/12089 [00:29<28:10,  6.90it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▌                                           | 430/12089 [00:29<28:11,  6.89it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▌                                           | 431/12089 [00:29<28:21,  6.85it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▌                                           | 432/12089 [00:29<28:41,  6.77it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▌                                           | 433/12089 [00:29<28:46,  6.75it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▌                                           | 434/12089 [00:29<28:43,  6.76it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▌                                           | 435/12089 [00:29<28:48,  6.74it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▌                                           | 436/12089 [00:30<28:46,  6.75it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▋                                           | 437/12089 [00:30<28:28,  6.82it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▋                                           | 438/12089 [00:30<28:41,  6.77it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▋                                           | 439/12089 [00:30<28:07,  6.90it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▋                                           | 440/12089 [00:30<28:47,  6.74it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▋                                           | 441/12089 [00:30<28:43,  6.76it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▋                                           | 442/12089 [00:30<28:45,  6.75it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▋                                           | 443/12089 [00:31<28:40,  6.77it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▋                                           | 444/12089 [00:31<29:09,  6.66it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▋                                           | 445/12089 [00:31<28:49,  6.73it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▋                                           | 446/12089 [00:31<28:47,  6.74it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▋                                           | 447/12089 [00:31<28:51,  6.72it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▋                                           | 448/12089 [00:31<28:24,  6.83it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▋                                           | 449/12089 [00:32<28:24,  6.83it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▋                                           | 450/12089 [00:32<28:26,  6.82it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▋                                           | 451/12089 [00:32<28:34,  6.79it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▋                                           | 452/12089 [00:32<28:38,  6.77it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▋                                           | 453/12089 [00:32<28:29,  6.81it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▋                                           | 454/12089 [00:32<28:46,  6.74it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▋                                           | 455/12089 [00:32<29:03,  6.67it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▋                                           | 456/12089 [00:33<29:08,  6.65it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▋                                           | 457/12089 [00:33<29:05,  6.67it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▋                                           | 458/12089 [00:33<29:06,  6.66it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▋                                           | 459/12089 [00:33<29:12,  6.64it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▋                                           | 460/12089 [00:33<28:52,  6.71it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▋                                           | 461/12089 [00:33<28:47,  6.73it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▋                                           | 462/12089 [00:33<29:04,  6.67it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▋                                           | 463/12089 [00:34<28:46,  6.73it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▋                                           | 464/12089 [00:34<29:14,  6.63it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▋                                           | 465/12089 [00:34<29:04,  6.66it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▋                                           | 466/12089 [00:34<28:50,  6.72it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▋                                           | 467/12089 [00:34<29:00,  6.68it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▋                                           | 468/12089 [00:34<28:43,  6.74it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:   4%|█▋                                           | 469/12089 [00:35<28:51,  6.71it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# ...
# Extracting MERT L5+L6 embeddings:  99%|██████████████████████████████████████████▊| 12019/12089 [34:45<00:12,  5.83it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:  99%|██████████████████████████████████████████▊| 12020/12089 [34:46<00:11,  5.94it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:  99%|██████████████████████████████████████████▊| 12021/12089 [34:46<00:11,  6.05it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:  99%|██████████████████████████████████████████▊| 12022/12089 [34:46<00:11,  6.08it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:  99%|██████████████████████████████████████████▊| 12023/12089 [34:46<00:12,  5.34it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:  99%|██████████████████████████████████████████▊| 12024/12089 [34:46<00:11,  5.53it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:  99%|██████████████████████████████████████████▊| 12025/12089 [34:46<00:11,  5.65it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:  99%|██████████████████████████████████████████▊| 12026/12089 [34:47<00:10,  5.83it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:  99%|██████████████████████████████████████████▊| 12027/12089 [34:47<00:10,  5.92it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings:  99%|██████████████████████████████████████████▊| 12028/12089 [34:47<00:10,  5.89it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▊| 12029/12089 [34:47<00:09,  6.04it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▊| 12030/12089 [34:47<00:09,  6.10it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▊| 12031/12089 [34:47<00:09,  5.92it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▊| 12032/12089 [34:48<00:09,  5.83it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▊| 12033/12089 [34:48<00:09,  5.76it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▊| 12034/12089 [34:48<00:09,  5.57it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▊| 12035/12089 [34:48<00:09,  5.43it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▊| 12036/12089 [34:48<00:09,  5.33it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▊| 12037/12089 [34:49<00:09,  5.26it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▊| 12038/12089 [34:49<00:09,  5.36it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▊| 12039/12089 [34:49<00:08,  5.61it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▊| 12040/12089 [34:49<00:08,  5.62it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▊| 12041/12089 [34:49<00:08,  5.73it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▊| 12042/12089 [34:49<00:08,  5.74it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▊| 12043/12089 [34:50<00:07,  5.82it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▊| 12044/12089 [34:50<00:07,  5.96it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▊| 12045/12089 [34:50<00:07,  6.02it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▊| 12046/12089 [34:50<00:07,  5.71it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▊| 12047/12089 [34:50<00:07,  5.42it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▊| 12048/12089 [34:50<00:07,  5.29it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▊| 12049/12089 [34:51<00:07,  5.12it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▊| 12050/12089 [34:51<00:07,  5.10it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▊| 12051/12089 [34:51<00:07,  5.09it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▊| 12052/12089 [34:51<00:07,  5.06it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▊| 12053/12089 [34:51<00:07,  5.06it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▉| 12054/12089 [34:52<00:06,  5.06it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▉| 12055/12089 [34:52<00:06,  5.05it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▉| 12056/12089 [34:52<00:06,  5.06it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▉| 12057/12089 [34:52<00:06,  5.15it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▉| 12058/12089 [34:52<00:05,  5.31it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▉| 12059/12089 [34:53<00:05,  5.50it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▉| 12060/12089 [34:53<00:05,  5.71it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▉| 12061/12089 [34:53<00:04,  5.69it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▉| 12062/12089 [34:53<00:04,  5.60it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▉| 12063/12089 [34:53<00:04,  5.43it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▉| 12064/12089 [34:54<00:04,  5.30it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▉| 12065/12089 [34:54<00:04,  5.23it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▉| 12066/12089 [34:54<00:04,  5.19it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▉| 12067/12089 [34:54<00:04,  5.19it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▉| 12068/12089 [34:54<00:04,  5.22it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▉| 12069/12089 [34:54<00:03,  5.29it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▉| 12070/12089 [34:55<00:03,  5.36it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▉| 12071/12089 [34:55<00:03,  5.36it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▉| 12072/12089 [34:55<00:03,  5.60it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▉| 12073/12089 [34:55<00:02,  5.72it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▉| 12074/12089 [34:55<00:02,  5.82it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▉| 12075/12089 [34:56<00:02,  5.89it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▉| 12076/12089 [34:56<00:02,  5.98it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▉| 12077/12089 [34:56<00:01,  6.01it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▉| 12078/12089 [34:56<00:01,  6.04it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▉| 12079/12089 [34:56<00:01,  6.03it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▉| 12080/12089 [34:56<00:01,  5.68it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▉| 12081/12089 [34:57<00:01,  5.84it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▉| 12082/12089 [34:57<00:01,  5.96it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▉| 12083/12089 [34:57<00:00,  6.02it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▉| 12084/12089 [34:57<00:00,  6.04it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▉| 12085/12089 [34:57<00:00,  6.12it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▉| 12086/12089 [34:57<00:00,  5.46it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▉| 12087/12089 [34:58<00:00,  5.33it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|██████████████████████████████████████████▉| 12088/12089 [34:58<00:00,  5.27it/s][src/libmpg123/id3.c:INT123_parse_new_id3():950] warning: ID3v2: unrealistic small tag lengh 0, skipping
# Extracting MERT L5+L6 embeddings: 100%|███████████████████████████████████████████| 12089/12089 [34:58<00:00,  5.76it/s]
